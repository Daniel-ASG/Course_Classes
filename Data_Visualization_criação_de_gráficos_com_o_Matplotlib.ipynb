# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-ASG/Aulas_de_cursos/blob/main/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com_o_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1
#
# ## Fazendo as primeiras visualizações

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/alura-cursos/curso-matplotlib/raw/preparando_ambiente/monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
# divisao = df.data.str.split(' ')
# df['data'] = divisao.str.get(0)
# df['hora'] = divisao.str.get(1)
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df.data = pd.to_datetime(df.data)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.data, df.temperatura);

# %%
plt.figure(figsize=(15,8))
plt.plot(df.data, df.temperatura);

# %%
plt.figure(figsize=(15,8))
plt.plot(df.data, df.temperatura)
plt.title('Temperatura no tempo');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura)

eixo.set_title('Temperatura no momento');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura)

eixo.set_title('Temperatura no momento')
eixo.set_ylabel('Temperatura')
eixo.set_xlabel('Data');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='green')

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %% [markdown]
# https://matplotlib.org/gallery/color/named_colors.html

# %% [markdown]
# # Aula 2
#
# ## Customizando nossas visualizações

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g', lw=4)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g', lw=0.4)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g', ls='dotted')

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g', marker='o')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df.data, df.temperatura, color='g')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True);

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4]);

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='best', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='best', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df.data, df.temperatura, color='b')
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10);

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df.data, df.temperatura, color='b')
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df.data, df.temperatura, color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em Maio/2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df.data, df.temperatura, color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df.data, df.temperatura, color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em Maio/2014', fontsize=25, pad=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

azul_esquerda = df.data < datetime.datetime(2014,5,1)
azul_direita = df.data > datetime.datetime(2014,6,1)

eixo2.plot(df.data, df.temperatura, color='g')
eixo2.plot(df[azul_esquerda].data, df[azul_esquerda].temperatura, color='b')
eixo2.plot(df[azul_direita].data, df[azul_direita].temperatura, color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['Temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %% [markdown]
# # Aula 3
#
# ## Anotações e diversos gráficos

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

eixo.axhline(max(df.temperatura), color='k', linestyle='--')
eixo.axhline(min(df.temperatura), color='k', linestyle='--');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)

eixo.annotate('Máximo', xy=(x1, y1), fontsize=20)

eixo.axhline(max(df.temperatura), color='k', linestyle='--')
eixo.axhline(min(df.temperatura), color='k', linestyle='--');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)
x2 = df.data[df.temperatura.idxmax() - 7000]
y2 = max(df.temperatura) - 5

eixo.annotate('Máximo', xy=(x1, y1), fontsize=20, xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df.temperatura), color='k', linestyle='--')
eixo.axhline(min(df.temperatura), color='k', linestyle='--');

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = df.data[df.temperatura.idxmax()]
y1 = max(df.temperatura)
x2 = df.data[df.temperatura.idxmax() - 7000]
y2 = max(df.temperatura) - 5
eixo.annotate('Máximo', xy=(x1, y1), fontsize=20, xytext=(x2,y2), arrowprops=dict(facecolor='k'))

x1 = df.data[df.temperatura.idxmin()]
y1 = min(df.temperatura)
x2 = df.data[df.temperatura.idxmin() - 7000]
y2 = min(df.temperatura) + 5
eixo.annotate('Mínimo', xy=(x1, y1), fontsize=20, xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df.temperatura), color='k', linestyle='--')
eixo.axhline(min(df.temperatura), color='k', linestyle='--');

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana').temperatura.mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores, edgecolor='black')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%', explode=explodir)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%', explode=explodir, shadow=True)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10);

# %% [markdown]
# # Aula 4
#
# ## Visualizando dados diferentes

# %%
iris = pd.read_csv('https://github.com/alura-cursos/curso-matplotlib/raw/preparando_ambiente/iris.csv')
iris.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(iris.comprimento_sépala, iris.largura_sépala)
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(iris.comprimento_sépala, iris.largura_sépala)
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'yellow', 'Iris-versicolor':'b', 'Iris-virginica':'r'}

for especie in iris.espécie.unique():
    tmp = iris[iris['espécie'] == especie]
    eixo.scatter(tmp.comprimento_sépala, tmp.largura_sépala, color=cores[especie])

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'yellow', 'Iris-versicolor':'b', 'Iris-virginica':'r'}
marcadores = {'Iris-setosa':'o', 'Iris-versicolor':'x', 'Iris-virginica':'+'}

for especie in iris.espécie.unique():
    tmp = iris[iris['espécie'] == especie]
    eixo.scatter(tmp.comprimento_sépala, tmp.largura_sépala, 
                 color=cores[especie], marker=marcadores[especie])

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20);

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'yellow', 'Iris-versicolor':'b', 'Iris-virginica':'r'}
marcadores = {'Iris-setosa':'o', 'Iris-versicolor':'x', 'Iris-virginica':'+'}

for especie in iris.espécie.unique():
    tmp = iris[iris['espécie'] == especie]
    eixo.scatter(tmp.comprimento_sépala, tmp.largura_sépala, 
                 color=cores[especie], marker=marcadores[especie], s=100)

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(iris.largura_pétala)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(['largura_pétala']);

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(iris.drop('espécie', axis=1).values)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(iris.drop('espécie', axis=1).columns);

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(iris.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(iris.drop('espécie', axis=1).columns);

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(iris.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(iris.drop('espécie', axis=1).columns);

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(iris.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(iris.drop('espécie', axis=1).columns);

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)

for outlier in caixas['fliers']:
    outlier.set(marker='x', markersize=8)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(iris.comprimento_pétala)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(iris.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(iris.comprimento_pétala, bins=20, density=True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

# %% [markdown]
# # Aula 5
#
# ## Customizando histogramas

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = iris.comprimento_pétala.mean(), iris.comprimento_pétala.std()

eixo.hist(iris.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.5,20), fontsize=20);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = iris.comprimento_pétala.mean(), iris.comprimento_pétala.std()

eixo.hist(iris.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
              xy=(4.5,20), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize=20);

# %% [markdown]
# https://matplotlib.org/3.1.3/api/markers_api.html

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = iris.comprimento_pétala.mean(), iris.comprimento_pétala.std()

eixo.hist(iris.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate(f'$\mu$ = {mu:.2f}\n$\sigma$ = {sigma:.2f}',
              xy=(4.5,20), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-1.15, 28), fontsize=20)

eixo.axvline(iris.comprimento_pétala.median(), color='r', linestyle='--')
eixo.annotate('mediana', xy=(iris.comprimento_pétala.median(), 31), fontsize=20);

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

iris_versicolor = iris[iris.espécie == 'Iris-versicolor']

mu, sigma = iris_versicolor.comprimento_pétala.mean(), iris_versicolor.comprimento_pétala.std()

eixo.hist(iris_versicolor.comprimento_pétala, bins=20)
eixo.set_title('Iris versicolor', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate(f'$\mu$ = {mu:.2f}\n$\sigma$ = {sigma:.2f}',
              xy=(3,6), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-0.43, 5.5), fontsize=20)

eixo.axvline(iris_versicolor.comprimento_pétala.median(), color='r', linestyle='--')
eixo.annotate('mediana', xy=(iris_versicolor.comprimento_pétala.median()+0.04, 6.9), 
              fontsize=20, color='r');

fig.savefig('histograma_Iris_versicolor.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

iris_setosa = iris[iris.espécie == 'Iris-setosa']

mu, sigma = iris_setosa.comprimento_pétala.mean(), iris_setosa.comprimento_pétala.std()

eixo.hist(iris_setosa.comprimento_pétala, bins=20)
eixo.set_title('Iris setosa', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate(f'$\mu$ = {mu:.2f}\n$\sigma$ = {sigma:.2f}',
              xy=(1.7, 7), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-0.18, 13.5), fontsize=20)

eixo.axvline(iris_setosa.comprimento_pétala.median(), color='r', linestyle='--')
eixo.annotate('mediana', xy=(iris_setosa.comprimento_pétala.median()+0.01, 12), 
              fontsize=20, color='r');

fig.savefig('histograma_Iris_setosa.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

iris_virginica = iris[iris.espécie == 'Iris-virginica']

mu, sigma = iris_virginica.comprimento_pétala.mean(), iris_virginica.comprimento_pétala.std()

eixo.hist(iris_virginica.comprimento_pétala, bins=20)
eixo.set_title('Iris virgínica', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True);

eixo.annotate(f'$\mu$ = {mu:.2f}\n$\sigma$ = {sigma:.2f}',
              xy=(6.3, 7), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu, 8), fontsize=20)

eixo.axvline(iris_virginica.comprimento_pétala.median(), color='r', linestyle='--')
eixo.annotate('mediana', xy=(iris_virginica.comprimento_pétala.median(),7), 
              fontsize=20, color='r');

fig.savefig('histograma_Iris_virginica.png', bbox_inches='tight')

# %%
from PIL import Image

# %%
largura, altura = Image.open('histograma_Iris_versicolor.png').size
combinada = Image.new('RGB', (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_Iris_versicolor.png',
                               'histograma_Iris_setosa.png',
                               'histograma_Iris_virginica.png']):
    combinada.paste(imagem, (intervalo, 0))
    intervalo += largura

combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1161x361 at 0x7FB2DC924780>
